# %%
import mediapipe as mp
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
img = cv2.imread(r"C:/Users/james/Desktop/Train_steering_wheel/make_yolo/data/images/val/img_173.jpg")

rgb = img[:,:,::-1]

plt.imshow(img[:,:,::-1])

# %%
# 447,87
# 552,323
#0 0.86796875 0.49895833333333334 0.19843749999999993 0.4354166666666667
# 0.7804,0.4270 
# 
555, 239
rgb = img[:,:,::-1]
plt.plot(500, 205, "og", markersize=10)
plt.plot(447, 87, "og", markersize=10)
plt.plot(552, 323, "og", markersize=10)
plt.imshow(rgb)
plt.show()
