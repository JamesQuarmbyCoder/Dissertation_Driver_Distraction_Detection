# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8n.pt")

# %%
results = model.train(data="data_config.yaml", epochs = 10)
# Out:
# New https://pypi.org/project/ultralytics/8.0.149 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.128  Python-3.10.11 torch-2.0.1+cpu CPU
# ...
